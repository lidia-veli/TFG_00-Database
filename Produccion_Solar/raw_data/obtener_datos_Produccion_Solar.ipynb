#                     SE            SI            SK   TR   UK
# Date
# 1979-01-01  216.880367   2913.422622   7584.036938  0.0  0.0
# 1979-01-02  114.249470  11425.991281  13747.527596  0.0  0.0
# 1979-01-03  160.281924  12531.554748  18215.256720  0.0  0.0
# 1979-01-04  142.440229   8186.146990  19764.984881  0.0  0.0
# 1979-01-05  165.105372  12799.568036  25074.940568  0.0  0.0
#
# [5 rows x 39 columns]

# %%
# quitar columna Date
data_PSF.drop(columns=['Date'], inplace=True)

# %%
# lista de países en los datos
paises_PSF = data_PSF.columns.to_list()
print(f'{len(paises_PSF)} países en los datos')
print(paises_PSF)
# Out:
# 38 países en los datos
# ['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT', 'LI', 'LT', 'LU', 'LV', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK', 'TR', 'UK']

# %% [markdown]
# ### Datos nulos

# %%
# crear un datatframe del número de valores nulos que tiene cada país
nulos_PSF = pd.DataFrame(data_PSF.isnull().sum(), columns=['Num_Null'])
#nulos_PSF

# NO HAY NULOS

# %%
# veamos si hay datos con valor cero
nulos_PSF['Num_Zero'] = data_PSF[data_PSF == 0].count()

nulos_PSF_pais1 = nulos_PSF[nulos_PSF['Num_Zero'] == 0]
nulos_PSF_pais2 = nulos_PSF[nulos_PSF['Num_Zero'] > 0]
nulos_PSF_pais2  # con valores cero
# Out:
#     Num_Null  Num_Zero
# IS         0     16892
# LI         0     16892
# MT         0     16892
# TR         0     16892
# UK         0     16892

# %%
# comprobamos que la suma total de las filas _pais1 y _pais2 es igual al de nulos_PSF
bool_PSF = nulos_PSF['Num_Null'].sum() == nulos_PSF_pais1['Num_Null'].sum() + nulos_PSF_pais2['Num_Null'].sum()
print(f'{bool_PSF} coinciden las cifras')
print()
print(f"Paises de interés: {len(nulos_PSF_pais1)}")
print(nulos_PSF_pais1.index.tolist())
print()
print(f"Paises con todos los datos vacíos: {len(nulos_PSF_pais2)}")
print(nulos_PSF_pais2.index.tolist())
# Out:
# True coinciden las cifras
#
# Paises de interés: 33
# ['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'ME', 'MK', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK']
#
# Paises con todos los datos vacíos: 5
# ['IS', 'LI', 'MT', 'TR', 'UK']

# %% [markdown]
# ## Exportar datos 1980 - 2024

# %%
data_PSF_csv = data_PSF.loc['1980-01-01':'2024-12-31']
data_PSF_csv.head()
# Out:
#                   AL           AT         BA           BE           BG  \
# Date
# 1980-01-01  1.487886  2417.894588  32.429328  3710.643482  1265.097344
# 1980-01-02  0.693366  2097.855527  19.836488  5470.239386  2166.897301
# 1980-01-03  1.039541  2240.282388  14.117529  2017.337831   985.414582
# 1980-01-04  3.016585  3147.451403  37.900500   487.819815  1649.676196
