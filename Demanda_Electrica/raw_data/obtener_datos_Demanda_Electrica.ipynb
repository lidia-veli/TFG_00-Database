# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_DE = pd.read_csv('raw_data_Demanda_Electrica.csv',
                         skiprows=53)
data_DE.head()
# Out:
#          Date        AT       BA        BE        BG        CH       CY  \
# 0  1979/01/01  176514.3  35070.8  258054.1   83038.0  220060.1   9874.4
# 1  1979/01/02  213039.2  37647.9  292989.9  113936.0  235095.5  11464.5
# 2  1979/01/03  219072.9  40690.1  295576.4  128486.0  234080.7  11874.1
# 3  1979/01/04  222644.7  41239.8  291382.5  131505.3  235966.4  13985.3
# 4  1979/01/05  223514.0  40801.6  295255.1  132363.3  230683.6  14689.1
#
#          CZ         DE        DK  ...        NL        NO        PL        PT  \
# 0  207395.8  1324992.0   98759.0  ...  302990.0  532011.2  391863.9  112389.4
# 1  237659.6  1489543.3  111813.5  ...  356807.5  541881.4  464883.0  139130.9
# 2  239119.1  1530437.2  114053.7  ...  353591.4  547741.5  483663.1  144728.5
# 3  238099.9  1540992.9  115368.3  ...  355602.8  548473.8  486924.3  145464.3
# 4  235368.1  1489922.4  113062.2  ...  354296.1  547225.9  452547.5  149202.7
#
#          RO        RS        SE       SI       SK         UK
# ...

# %% [markdown]
# ## 1) PREPROCESAMIENTO DATOS

# %% [markdown]
# ### Indexar por fecha

# %%
# indexar por fecha
data_DE.index = pd.to_datetime(data_DE['Date'])
data_DE.head()
# Out:
#                   Date        AT       BA        BE        BG        CH  \
# Date
# 1979-01-01  1979/01/01  176514.3  35070.8  258054.1   83038.0  220060.1
# 1979-01-02  1979/01/02  213039.2  37647.9  292989.9  113936.0  235095.5
# 1979-01-03  1979/01/03  219072.9  40690.1  295576.4  128486.0  234080.7
# 1979-01-04  1979/01/04  222644.7  41239.8  291382.5  131505.3  235966.4
# 1979-01-05  1979/01/05  223514.0  40801.6  295255.1  132363.3  230683.6
#
#                  CY        CZ         DE        DK  ...        NL        NO  \
# Date                                                ...
# 1979-01-01   9874.4  207395.8  1324992.0   98759.0  ...  302990.0  532011.2
# 1979-01-02  11464.5  237659.6  1489543.3  111813.5  ...  356807.5  541881.4
# 1979-01-03  11874.1  239119.1  1530437.2  114053.7  ...  353591.4  547741.5
# 1979-01-04  13985.3  238099.9  1540992.9  115368.3  ...  355602.8  548473.8
# 1979-01-05  14689.1  235368.1  1489922.4  113062.2  ...  354296.1  547225.9
#
# ...

# %%
# quitar columna Date
data_DE.drop(columns=['Date'], inplace=True)

# %%
# lista de países en los datos
paises_DE = data_DE.columns.to_list()
print(f'{len(paises_DE)} paises')
print(paises_DE)
# Out:
# 33 paises
# ['AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'ME', 'MK', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK', 'UK']

# %% [markdown]
# ### Datos nulos
# en estos datos no hay nulos ni vacíos

# %%
# crear un datatframe del número de valores nulos que tiene cada país
nulos_DE = pd.DataFrame(data_DE.isnull().sum(), columns=['Num_Null'])
#nulos_DE

# parece que no hay datos nulos, pero veamos si hay ceros
nulos_DE['Num_Zero'] = nulos_DE.isin([0]).sum()
#nulos_DE

# NO HAY

# %% [markdown]
# ## Exportar datos 1980 - 2024

# %%
# queremos los datos del 1979-01-01 hasta el 2024-12-31
data_DE_csv = data_DE.loc['1980-01-01':'2024-12-31']
data_DE_csv.head()
# Out:
#                   AT       BA        BE        BG        CH       CY  \
# Date
# 1980-01-01  175175.1  37003.7  207573.1  106164.2  178332.3  11206.9
# 1980-01-02  204638.6  37910.2  244888.8  124172.8  184710.5  12876.0
# 1980-01-03  208766.2  39716.9  254312.1  127410.6  185513.2  13054.6
# 1980-01-04  212804.2  40129.1  253043.5  131845.0  183997.8  13338.2
# 1980-01-05  193156.9  40148.8  232114.1  127506.7  172282.9  13057.9
#
#                   CZ         DE        DK       EE  ...        NL        NO  \
# Date                                                ...
# 1980-01-01  155893.0  1112427.7   92109.9  23510.8  ...  300964.2  428078.5
# 1980-01-02  189653.3  1350065.4  102485.9  26330.1  ...  330623.7  478934.3
# 1980-01-03  196708.2  1407802.0  106657.7  27108.5  ...  335344.2  498853.3
# 1980-01-04  198471.6  1440117.2  106468.5  27587.1  ...  333897.5  503246.2
# 1980-01-05  185201.7  1262532.5   93613.8  25645.3  ...  299799.9  478169.0
#
# ...

# %%
data_DE_csv.tail()
# Out:
#                   AT       BA        BE        BG        CH       CY  \
# Date
# 2024-12-27  186544.5  38247.3  232580.3  119202.4  166495.1  13343.5
# 2024-12-28  181900.1  38998.9  222675.8  118599.7  163765.7  12202.2
# 2024-12-29  170976.1  38195.1  216946.8  117289.5  160114.8  11781.1
# 2024-12-30  197031.6  39499.8  232987.6  120650.7  174118.9  13858.3
# 2024-12-31  194454.4  38088.1  242253.6  120503.0  175544.3  12202.5
#
#                   CZ         DE       DK       EE  ...        NL        NO  \
# Date                                               ...
# 2024-12-27  158428.8  1261014.7  87909.4  21874.2  ...  297565.4  402892.6
# 2024-12-28  157227.7  1247366.6  85524.8  21551.7  ...  300605.8  381513.0
# 2024-12-29  155515.0  1143856.6  84080.5  20923.4  ...  283068.9  376812.7
# 2024-12-30  177666.4  1325192.9  95005.7  22618.8  ...  318276.6  408517.7
# 2024-12-31  153708.9  1340213.7  89232.1  21515.7  ...  309439.6  427133.9
#
# ...

# %%
data_DE_csv.to_csv('../data_DE_1980_2024.csv', index=True)
