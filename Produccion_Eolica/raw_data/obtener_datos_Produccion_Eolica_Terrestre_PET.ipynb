# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_ETERR = pd.read_csv('raw_data_Produccion_Eolica_Terrestre.csv',
                         skiprows=52)
data_ETERR.head()
# Out:
#          Date   AL            AT          BA            BE           BG  \
# 0  1979-01-01  0.0  34155.846207  385.707784  11812.688686  4836.289819
# 1  1979-01-02  0.0  38577.988709  558.271865  32050.692709  5215.795699
# 2  1979-01-03  0.0  26620.878650  199.815063  18437.499639  7016.805052
# 3  1979-01-04  0.0   8810.414211  131.408002  47140.099064  6108.620991
# 4  1979-01-05  0.0   2318.891201   34.507274  36156.484855  4164.283709
#
#            CH           CY           CZ             DE  ...            NO  \
# 0  419.964504  1064.761330  4449.338587  548419.308920  ...  27063.964019
# 1  198.240374  1953.556022  6467.563464  582861.798744  ...  17075.666413
# 2  148.611503  2610.755922  5684.954766  604742.998680  ...  17156.812317
# 3  114.122657  2641.659636  2654.572997  346170.701532  ...  18508.645385
# 4   22.680300   390.589021  1102.464575  174371.810432  ...  16259.559167
#
#              PL          PT            RO         RS         SE            SI  \
# ...

# %% [markdown]
# ## 1) PREPROCESAMIENTO DATOS

# %% [markdown]
# ### Indexar por fecha

# %%
# indexar por fecha
data_ETERR.index = pd.to_datetime(data_ETERR['Date'])
data_ETERR.head()
# Out:
#                   Date   AL            AT          BA            BE  \
# Date
# 1979-01-01  1979-01-01  0.0  34155.846207  385.707784  11812.688686
# 1979-01-02  1979-01-02  0.0  38577.988709  558.271865  32050.692709
# 1979-01-03  1979-01-03  0.0  26620.878650  199.815063  18437.499639
# 1979-01-04  1979-01-04  0.0   8810.414211  131.408002  47140.099064
# 1979-01-05  1979-01-05  0.0   2318.891201   34.507274  36156.484855
#
#                      BG          CH           CY           CZ             DE  \
# Date
# 1979-01-01  4836.289819  419.964504  1064.761330  4449.338587  548419.308920
# 1979-01-02  5215.795699  198.240374  1953.556022  6467.563464  582861.798744
# 1979-01-03  7016.805052  148.611503  2610.755922  5684.954766  604742.998680
# 1979-01-04  6108.620991  114.122657  2641.659636  2654.572997  346170.701532
# 1979-01-05  4164.283709   22.680300   390.589021  1102.464575  174371.810432
#
#             ...            NO            PL          PT            RO  \
# ...

# %%
# quitar columna Date
data_ETERR.drop(columns=['Date'], inplace=True)

# %%
paises_ETERR = data_ETERR.columns.to_list()
print(f'{len(paises_ETERR)} paises')
print(paises_ETERR)
# Out:
# 38 paises
# ['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT', 'LI', 'LT', 'LU', 'LV', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK', 'TR', 'UK']

# %% [markdown]
# ### Datos nulos

# %%
# crear un datatframe del número de valores nulos que tiene cada país
nulos_ETERR = pd.DataFrame(data_ETERR.isnull().sum(), columns=['Num_Null'])
#nulos_ETERR

# NO HAY NULOS

# %%
# parece que no hay datos nulos, pero veamos si hay ceros
nulos_ETERR['Num_Zero'] = data_ETERR.isin([0]).sum()
#nulos_ETERR

# HAY PAÍSES SIN VALORES CERO, Y PAÍSES CON TODO (16861) VALORES CERO

# %%
# hay algunos países con todo ceros
nulos_ETERR_pais1 = nulos_ETERR[nulos_ETERR['Num_Zero'] == 0]
nulos_ETERR_pais2 = nulos_ETERR[nulos_ETERR['Num_Zero'] == 16861]

# comprobamos que la suma total de las filas _pais1 y _pais2 es igual al de nulos_ETERR
bool_ETERR = nulos_ETERR['Num_Null'].sum() == nulos_ETERR_pais1['Num_Null'].sum() + nulos_ETERR_pais2['Num_Null'].sum()
print(f'{bool_ETERR} coinciden las cifras')
print()
print(f"Paises sin nulos: {len(nulos_ETERR_pais1)}")
print(nulos_ETERR_pais1.index.tolist())
print()
print(f"Paises con todo nulos: {len(nulos_ETERR_pais2)}")
print(nulos_ETERR_pais2.index.tolist())
# Out:
# True coinciden las cifras
#
# Paises sin nulos: 33
# ['AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'ME', 'MK', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK']
#
# Paises con todo nulos: 5
# ['AL', 'LI', 'MT', 'TR', 'UK']

# %% [markdown]
# ## Exportar datos 1979 - 2024

# %%
# queremos los datos del 1979-01-01 hasta el 2024-12-31
data_ETERR_csv = data_ETERR.loc['1980-01-01':'2024-12-31']
data_ETERR_csv.head()
# Out:
#              AL            AT          BA            BE            BG  \
# Date
# 1980-01-01  0.0  26612.497926  351.783091  24127.676909  10933.272021
# 1980-01-02  0.0  16565.648211  130.508337  25150.614100   4214.992590
# 1980-01-03  0.0  24171.437781  701.919827  17113.298861   6665.371105
# 1980-01-04  0.0   8135.453167  280.716809  43587.597705   6920.259467
# 1980-01-05  0.0   1896.463726   59.542003  25614.472966   2268.405128
#
#                     CH           CY           CZ             DE            DK  \
# Date
# 1980-01-01   67.857139  1802.105181  3936.220762  610782.578593  18967.502057
# 1980-01-02  116.051623   887.028757  3220.160405  464394.676157  44800.167121
# 1980-01-03   64.771056   612.501102  2973.266553  198748.012443  21512.712085
# 1980-01-04   64.501542  1655.827733   999.514339  552802.965018  76096.986121
# 1980-01-05   82.731903  1638.089369   982.623535  267857.788850  40897.969280
#
# ...

# %%
data_ETERR_csv.tail()
# Out:
#              AL           AT         BA            BE           BG         CH  \
# Date
# 2024-12-27  0.0  1582.325233  82.028223   2658.465655  4012.484123   4.813883
# 2024-12-28  0.0  1187.353015  35.821572   3047.236885  3072.351428   4.253936
# 2024-12-29  0.0  2136.535940   7.730528   6214.858464  1101.817781   6.261477
# 2024-12-30  0.0  2134.148786   0.365712  19691.077543   391.837123   2.411596
# 2024-12-31  0.0  1446.435654   2.077671  36550.089021   488.811213  24.778733
#
#                     CY           CZ             DE            DK  ...  \
# Date                                                              ...
# 2024-12-27  105.728315   200.835457   36025.687211   7214.223695  ...
# 2024-12-28   48.236397   154.641480   42073.429672  26090.064947  ...
# 2024-12-29   50.890598   711.161478  281521.426043  91398.112024  ...
# 2024-12-30  123.476818  1045.319559  551510.113426  85585.784422  ...
# 2024-12-31  821.429122  2032.268484  664360.169657  70481.374756  ...
# ...

# %%
data_ETERR_csv.to_csv('../data_PET_1980_2024.csv', index=True)
